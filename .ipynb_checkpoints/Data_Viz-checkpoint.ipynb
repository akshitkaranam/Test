# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# IMF Growth
df_imf_growth = pd.read_excel("./Data/Growth_IMF.xls")

# %%
data = df_imf_growth[df_imf_growth["Real GDP growth (Annual percent change)"] == "Singapore"]

# %%
data = data.drop("Real GDP growth (Annual percent change)",axis=1)
data
# Out:
#      1980  1981 1982 1983 1984 1985 1986  1987  1988  1989  ... 2019 2020  \
# 155  10.1  10.8  7.1  8.6  8.8 -0.6  1.3  10.8  11.3  10.2  ...  1.3 -3.9
#
#     2021 2022 2023 2024 2025 2026 2027 2028
# 155  8.9  3.6    1  2.1  2.5  2.5  2.5  2.5
#
# [1 rows x 49 columns]

# %%
data.columns
# Out:
# Index([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027,
#        2028],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

x = list(data.columns)  
y = data.iloc[0].tolist()  

negative_indices = [i for i, value in enumerate(y) if value < 0]

# Plot circles at the points where y is less than 0 and add text labels
x_negative = [x[i] for i in negative_indices]
y_negative = [y[i] for i in negative_indices]

# Create a single line plot for the entire dataset
plt.plot(x, y, color='blue', label='Line')

# Plot circles at the points where y is less than 0 and add text labels
plt.scatter(x_negative, y_negative, color='red', marker='o')

# Add a horizontal line at y=0
plt.axhline(0, color='red', linestyle='--')

# Create a line plot for x > 2022 with a different style (green)
x_index = x.index(2022)
plt.plot(x[x_index:], y[x_index:], color='green', label='Line (x > 2022)')

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('GDP Growth')
plt.title('Real GDP Growth (1980-2022)')

# Display the plot
plt.savefig('gdp_growth.png',transparent=True)
plt.show()

# %%
ind_df = pd.read_excel("./Data/Singapore_Industry.xlsx")

# %%
ind_df = ind_df.dropna()

# %%
Goods_Producing_Industries = ind_df.iloc[0:3].reset_index(drop=True)

# %%
Service_Industries= ind_df.iloc[4:-1].reset_index(drop=True)

# %%
Goods_Producing_Industries
# Out:
#        Data Series  2022   2021   2020   2019   2018   2017   2016   2015   \
# 0    Manufacturing   21.6   22.0   20.7   20.4   21.9   19.8   18.6   19.2
# 1     Construction    2.7    2.6    2.4    3.7    3.7    4.0    4.8    5.1
# 2        Utilities    1.1    1.2    1.4    1.2    1.2    1.2    1.4    1.5
#
#    2014   ...  1969   1968   1967   1966   1965   1964   1963   1962   1961   \
# 0   19.0  ...   17.1   15.9   15.2   14.9   14.3   13.5   12.2   11.3   10.9
# 1    5.1  ...    5.9      6    5.6    5.6    6.3    5.8    4.8    4.3    4.2
# 2    1.4  ...      3    3.3    3.3      3    2.9    3.1    2.7    2.9    2.7
#
#   1960
# 0  11.2
# 1   3.3
# 2   2.8
#
# [3 rows x 64 columns]

# %%
Service_Industries = Service_Industries.sort_values(by=["2022 "],ascending=False).reset_index(drop=True)
Goods_Producing_Industries = Goods_Producing_Industries.sort_values(by=["2022 "],ascending=False).reset_index(drop=True)

# %%
Goods_Producing_Industries['2022 ']
# Out:
# 0    21.6
# 1     2.7
# 2     1.1
# Name: 2022 , dtype: float64

# %%
# Libraries
import matplotlib.pyplot as plt
 
# Make data: I have 3 groups and 7 subgroups
group_names=["Service Industry", "Goods Producing Industry", "Ownership of Dwellings"]
group_size=[Service_Industries['2022 '].sum(), Goods_Producing_Industries['2022 '].sum(), ind_df['2022 '][20]]
subgroup_names_raw = Service_Industries['Data Series'].tolist()
subgroup_names_raw.extend(Goods_Producing_Industries['Data Series'].tolist())
subgroup_names_raw.append("Ownership of Dwellings")
supgroup_names = []
for name in subgroup_names_raw:
    supgroup_names.append(name.strip())
subgroup_size=[]
subgroup_size = Service_Industries['2022 '].tolist()
subgroup_size.extend(Goods_Producing_Industries['2022 '].tolist())
subgroup_size.append(ind_df['2022 '][20])

 
# Create colors
a, b, c=[plt.cm.Blues, plt.cm.Reds, plt.cm.Greens]
 
# First Ring (outside)
fig, ax = plt.subplots()
ax.axis('equal')
mypie, _ = ax.pie(group_size, radius=1.3, labels=group_names, colors=[a(0.6), b(0.6), c(0.6)] )
plt.setp( mypie, width=0.3, edgecolor='white')
 
# Second Ring (Inside)
colors=[]
for i in  range(1,len(Service_Industries['Data Series'].tolist())+1):
    i * 0.1
    colors.append(a(i*0.1))
for i in  range(1,len(Goods_Producing_Industries['Data Series'].tolist())+1):
    i * 0.1
    colors.append(b(i*0.1))
colors.append(c(0.6))

mypie2, _ = ax.pie(subgroup_size, radius=1.3-0.3, labels=supgroup_names, labeldistance=0.7,colors=colors)
plt.setp( mypie2, width=0.4, edgecolor='white')
plt.margins(0,0)
 
# show it
plt.show()

# %%
import plotly.io as pio
pio.renderers.default='notebook'

# %%
# Libraries
import matplotlib.pyplot as plt
import mpldatacursor

# Make data: I have 3 groups and 7 subgroups
group_names = ["Service Industry", "Goods Producing Industry", "Ownership of Dwellings"]
group_size = [Service_Industries['2022 '].sum(), Goods_Producing_Industries['2022 '].sum(), ind_df['2022 '][20]]
subgroup_names_raw = Service_Industries['Data Series'].tolist()
subgroup_names_raw.extend(Goods_Producing_Industries['Data Series'].tolist())
subgroup_names_raw.append("Ownership of Dwellings")
subgroup_names = [name.strip() for name in subgroup_names_raw]
subgroup_size = Service_Industries['2022 '].tolist()
subgroup_size.extend(Goods_Producing_Industries['2022 '].tolist())
subgroup_size.append(ind_df['2022 '][20])

# Create colors
a, b, c = [plt.cm.Blues, plt.cm.Reds, plt.cm.Greens]

# First Ring (outside)
fig, ax = plt.subplots()
ax.axis('equal')
mypie, _ = ax.pie(group_size, radius=1.3, labels=group_names, colors=[a(0.6), b(0.6), c(0.6)])
plt.setp(mypie, width=0.3, edgecolor='white')

# Second Ring (Inside)
colors = []
for i in range(1, len(subgroup_names) + 1):
    i * 0.1
    colors.append(a(i * 0.1))
for i in range(1, len(subgroup_names) + 1):
    i * 0.1
    colors.append(b(i * 0.1))
colors.append(c(0.6))

mypie2, _ = ax.pie(subgroup_size, radius=1.3 - 0.3, labeldistance=0.7, colors=colors)
plt.setp(mypie2, width=0.4, edgecolor='white')
plt.margins(0, 0)

# Add interactive labels and values when hovering
mpldatacursor.datacursor(hover=True, point_labels=subgroup_names, display='multiple', bbox=dict(fc='w', alpha=1))

# Show the interactive plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 40
#      37 plt.margins(0, 0)
#      39 # Add interactive labels and values when hovering
# ---> 40 mpldatacursor.datacursor(hover=True, point_labels=subgroup_names, display='multiple', bbox=dict(fc='w', alpha=1))
#      42 # Show the interactive plot
#      43 plt.show()
#
# File ~/anaconda3/envs/torchenv/lib/python3.11/site-packages/mpldatacursor/convenience.py:169, in datacursor(artists, axes, **kwargs)
#     166 if artists is None:
#     167     artists = [artist for ax in axes for artist in plotted_artists(ax)]
# --> 169 return DataCursor(artists, **kwargs)
#
# File ~/anaconda3/envs/torchenv/lib/python3.11/site-packages/mpldatacursor/datacursor.py:204, in DataCursor.__init__(self, artists, tolerance, formatter, point_labels, display, draggable, hover, props_override, keybindings, date_format, display_button, hide_button, keep_inside, **kwargs)
#     202 if self.display is not 'multiple':
#     203     for ax in self.axes:
# --> 204         self.annotations[ax] = self.annotate(ax, **kwargs)
#     205         # Hide the annotation box until clicked...
#     206         self.annotations[ax].set_visible(False)
#
# File ~/anaconda3/envs/torchenv/lib/python3.11/site-packages/mpldatacursor/datacursor.py:444, in DataCursor.annotate(self, ax, **kwargs)
#     440 annotation._has_been_shown = False
#     442 # Place the annotation in the figure instead of the axes so that it
#     443 # doesn't get hidden behind other subplots (zorder won't fix that).
# --> 444 ax.figure.texts.append(ax.texts.pop())
#     446 # Create a draggable annotation box, if required.
#     447 if self.draggable:
#
# AttributeError: 'ArtistList' object has no attribute 'pop'

# %%
import plotly.graph_objects as go

# Make data: I have 3 groups and 7 subgroups
group_names = ["Service Industry", "Goods Producing Industry", "Ownership of Dwellings"]
group_size = [Service_Industries['2022 '].sum(), Goods_Producing_Industries['2022 '].sum(), ind_df['2022 '][20]]
subgroup_names_raw = Service_Industries['Data Series'].tolist()
subgroup_names_raw.extend(Goods_Producing_Industries['Data Series'].tolist())
subgroup_names_raw.append("Ownership of Dwellings")
subgroup_names = [name.strip() for name in subgroup_names_raw]
subgroup_size = Service_Industries['2022 '].tolist()
subgroup_size.extend(Goods_Producing_Industries['2022 '].tolist())
subgroup_size.append(ind_df['2022 '][20])

# Create colors
colors = ['blue', 'red', 'green']

# Create a Pie chart figure
fig = go.Figure()

# Add the outer ring (group) to the figure
fig.add_trace(go.Pie(
    labels=group_names,
    values=group_size,
    marker=dict(colors=colors),
    hole=0.3,
    hoverinfo='label+percent+name'  # Display label, percent, and name on hover
))

# Add the inner ring (subgroup) to the figure
fig.add_trace(go.Pie(
    labels=subgroup_names,
    values=subgroup_size,
    marker=dict(colors=colors * 6),  # Repeating the colors for the subgroups
    hole=0.6,
    hoverinfo='label+percent'  # Display label and percent on hover
))

# Set the layout and title
fig.update_layout(
    title="Interactive Donut Chart",
    legend_title_text="Categories"
)

# Show the interactive plot
fig.write_html('first_figure.html', auto_open=True)

# %%
# Make data: I have 3 groups and 7 subgroups
group_names = ["Service Industry", "Goods Producing Industry", "Ownership of Dwellings"]
group_size = [Service_Industries['2022 '].sum(), Goods_Producing_Industries['2022 '].sum(), ind_df['2022 '][20]]
subgroup_names_raw = Service_Industries['Data Series'].tolist()
subgroup_names_raw.extend(Goods_Producing_Industries['Data Series'].tolist())
subgroup_names_raw.append("Ownership of Dwellings")
subgroup_names = [name.strip() for name in subgroup_names_raw]
subgroup_size = Service_Industries['2022 '].tolist()
subgroup_size.extend(Goods_Producing_Industries['2022 '].tolist())
subgroup_size.append(ind_df['2022 '][20])

# Create colors
colors = ['blue', 'red', 'green']

# Create a Pie chart figure
fig = go.Figure()

# Add the outer ring (group) to the figure
fig.add_trace(go.Pie(
    labels=group_names,
    values=group_size,
    marker=dict(colors=colors),
    hole=0.1,  # Adjust the hole size to control the alignment
    hoverinfo='label+percent+name'  # Display label, percent, and name on hover
))

# Calculate the angles for the inner ring
total_values = sum(subgroup_size)
angles = [val / total_values * 360 for val in subgroup_size]

# Add the inner ring (subgroup) to the figure
fig.add_trace(go.Pie(
    labels=subgroup_names,
    values=subgroup_size,
    marker=dict(colors=colors * 6),  # Repeating the colors for the subgroups
    hole=0.4,  # Match the hole size with the outer ring
    rotation=90,  # Rotate the inner ring to align with the outer ring
    direction="clockwise",  # Set direction to ensure alignment
    sort=False,  # Disable sorting to maintain order
    hoverinfo='label+percent'  # Display label and percent on hover
))

# Set the layout and title
fig.update_layout(
    title="Interactive Donut Chart",
    legend_title_text="Categories"
)

# Show the interactive plot
fig.write_html('first_figure.html', auto_open=True)

# %%
import plotly.graph_objects as go

# Make data: I have 3 groups and 7 subgroups
labels = ["Service Industry", "Goods Producing Industry", "Ownership of Dwellings"]
outer_values = [Service_Industries['2022 '].sum(), Goods_Producing_Industries['2022 '].sum(), ind_df['2022 '][20]]

subgroup_names_raw = Service_Industries['Data Series'].tolist()
subgroup_names_raw.extend(Goods_Producing_Industries['Data Series'].tolist())
subgroup_names_raw.append("Ownership of Dwellings")
subgroup_names = [name.strip() for name in subgroup_names_raw]
inner_values = Service_Industries['2022 '].tolist()
inner_values.extend(Goods_Producing_Industries['2022 '].tolist())
inner_values.append(ind_df['2022 '][20])

trace1 = go.Pie(
    hole=0.5,
    sort=False,
    direction='clockwise',
    domain={'x': [0.15, 0.85], 'y': [0.15, 0.85]},
    values=inner_values,
    textinfo='percent+label',  # Display label and percentage only
    textposition='inside',
    labels=subgroup_names,
    marker={'line': {'color': 'white', 'width': 1}
    }
)

trace2 = go.Pie(
    hole=0.7,
    sort=False,
    direction='clockwise',
    values=outer_values,
    labels=labels,
    textinfo='percent+label',  # Display label and percentage only
    textposition='outside',
    marker={'colors': ['green', 'red', 'blue'],
            'line': {'color': 'white', 'width': 1}
    }
)

fig = go.FigureWidget(data=[trace1, trace2])
fig.write_html('first_figure.html', auto_open=True)
